# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmila-Nri/Python-mini-project-/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
age=[]
height=[]
weight=[]
speed=[]
for _ in range (100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
  idata = {'age':age,'height': height, 'weight': weight,'speed': speed}

# %%
idata
# Out:
# {'age': [1,
#   38,
#   19,
#   10,
#   5,
#   55,
#   62,
#   38,
#   14,
#   49,
#   35,
#   33,
#   12,
#   4,
#   84,
#   62,
#   66,
#   57,
#   19,
#   67,
#   81,
#   39,
#   5,
#   86,
#   26,
#   71,
#   0,
#   17,
#   84,
#   87,
#   26,
#   94,
#   3,
#   26,
#   91,
#   24,
#   31,
#   22,
#   73,
#   44,
#   68,
#   92,
#   55,
#   20,
#   78,
#   18,
#   35,
#   45,
#   95,
#   24,
#   31,
#   45,
#   90,
#   10,
#   85,
#   58,
#   86,
#   84,
#   71,
#   47,
#   67,
#   42,
#   11,
#   84,
#   79,
#   83,
#   71,
#   74,
#   68,
#   18,
#   97,
#   22,
#   18,
#   80,
#   65,
#   35,
#   14,
#   4,
#   54,
#   20,
#   100,
#   36,
#   96,
#   3,
#   16,
#   3,
#   35,
#   76,
#   86,
#   18,
#   76,
#   82,
#   4,
#   4,
#   54,
#   44,
#   85,
#   32,
#   21,
#   37],
#  'height': [30,
#   56,
#   80,
#   83,
#   41,
#   9,
#   27,
#   49,
#   19,
#   4,
#   26,
#   0,
#   18,
#   41,
#   20,
#   60,
#   32,
#   18,
#   30,
#   5,
#   7,
#   17,
#   76,
#   50,
#   13,
#   79,
#   47,
#   69,
#   86,
#   74,
#   67,
#   24,
#   95,
#   17,
#   86,
#   49,
#   63,
#   41,
#   86,
#   92,
#   6,
#   75,
#   24,
#   86,
#   12,
#   30,
#   82,
#   15,
#   79,
#   13,
#   8,
#   84,
#   0,
#   84,
#   22,
#   46,
#   41,
#   72,
#   16,
#   71,
#   73,
#   56,
#   16,
#   75,
#   46,
#   94,
#   88,
#   58,
#   100,
#   77,
#   62,
#   86,
#   85,
#   70,
#   15,
#   69,
#   91,
#   17,
#   73,
#   21,
#   67,
#   36,
#   98,
#   41,
#   14,
#   6,
#   85,
#   34,
#   16,
#   75,
#   95,
#   40,
#   86,
#   4,
#   30,
#   93,
#   61,
#   29,
#   86,
#   75],
#  'weight': [53,
#   9,
#   43,
#   73,
#   52,
#   32,
#   74,
#   85,
#   82,
#   93,
#   39,
#   76,
#   4,
#   32,
#   27,
#   78,
#   99,
#   62,
#   76,
#   39,
#   62,
#   17,
#   9,
#   64,
#   14,
#   54,
#   86,
#   47,
#   97,
#   4,
#   39,
#   39,
#   38,
#   1,
#   2,
#   68,
#   55,
#   40,
#   100,
#   54,
#   28,
#   80,
#   52,
#   71,
#   60,
#   86,
#   67,
#   99,
#   53,
#   94,
#   54,
#   54,
#   44,
#   55,
#   15,
#   10,
#   88,
#   17,
#   4,
#   35,
#   32,
#   78,
#   69,
#   10,
#   22,
#   66,
#   79,
#   60,
#   7,
#   42,
#   22,
#   60,
#   48,
#   38,
#   54,
#   77,
#   68,
#   62,
#   96,
#   51,
#   16,
#   34,
#   8,
#   88,
#   94,
#   83,
#   89,
#   68,
#   72,
#   70,
#   62,
#   52,
#   58,
#   24,
#   52,
#   87,
#   20,
#   35,
#   71,
#   19],
#  'speed': [93,
#   46,
#   45,
#   41,
#   72,
#   58,
#   84,
#   60,
#   29,
#   61,
#   48,
#   89,
#   67,
#   69,
#   95,
#   66,
#   8,
#   61,
#   8,
#   89,
#   35,
#   42,
#   43,
#   56,
#   18,
#   98,
#   76,
#   32,
#   96,
#   44,
#   8,
#   47,
#   0,
#   7,
#   18,
#   4,
#   39,
#   81,
#   99,
#   87,
#   57,
#   7,
#   38,
#   99,
#   66,
#   18,
#   62,
#   31,
#   65,
#   9,
#   73,
#   42,
#   74,
#   21,
#   63,
#   19,
#   20,
#   87,
#   98,
#   51,
#   85,
#   85,
#   34,
#   66,
#   2,
#   16,
#   9,
#   39,
#   76,
#   41,
#   18,
#   75,
#   47,
#   67,
#   98,
#   67,
#   10,
#   29,
#   74,
#   13,
#   1,
#   26,
#   61,
#   73,
#   94,
#   19,
#   81,
#   33,
#   2,
#   82,
#   39,
#   94,
#   23,
#   58,
#   76,
#   2,
#   18,
#   41,
#   50,
#   30]}

# %%
df1 = pd.DataFrame(idata)

# %%
 df1.describe()
# Out:
#               age      height      weight       speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    55.090000   48.020000   51.740000   48.900000
# std     31.669727   31.458801   31.143402   29.132057
# min      0.000000    1.000000    0.000000    0.000000
# 25%     20.500000   19.500000   21.750000   23.000000
# 50%     62.000000   43.500000   54.500000   49.000000
# 75%     81.750000   80.000000   79.250000   69.000000
# max    100.000000   99.000000   99.000000  100.000000

# %%
df1[['age','height']]
# Out:
#     age  height
# 0    57      33
# 1    81      38
# 2    66       3
# 3    21       2
# 4    17      43
# ..  ...     ...
# 95    6      97
# 96  100      13
# 97   28       1
# 98   66      83
# 99   66      91
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['age','height']]
# Out:
#    age  height
# 0   57      33
# 3   21       2

# %%
df2 = df1[['age','height']]

# %%
df1.sort_index(ascending=True)
# Out:
#     age  height  weight  speed
# 0    57      33      97      5
# 1    81      38      32     64
# 2    66       3      41     23
# 3    21       2      38     13
# 4    17      43       1     78
# ..  ...     ...     ...    ...
# 95    6      97      84     67
# 96  100      13       9     13
# 97   28       1      66     59
# 98   66      83      70     34
# 99   66      91      13    100
#
# [100 rows x 4 columns]

# %%
df1[0::2]. describe()
# Out:
#               age     height     weight      speed
# count   50.000000  50.000000  50.000000  50.000000
# mean    51.540000  44.400000  57.780000  46.720000
# std     29.593994  31.826058  32.677952  29.149187
# min      0.000000   1.000000   1.000000   2.000000
# 25%     19.000000  16.250000  25.750000  23.000000
# 50%     59.000000  35.500000  67.000000  47.500000
# 75%     75.750000  78.500000  88.000000  68.750000
# max    100.000000  99.000000  98.000000  98.000000

# %%
# Filter
df1['weight']>50
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95     True
# 96    False
# 97     True
# 98     True
# 99    False
# Name: weight, Length: 100, dtype: bool

# %%
# Filter
filter1 = df1['weight']>50

# %%
df1[filter1]
# Out:
#     age  height  weight  speed
# 0    57      33      97      5
# 5    79       6      73     67
# 9    30      87      74     17
# 16   65      55      80     21
# 18   10      24      82     56
# 20    5      24      96     48
# 21    9      40      56     41
# 22   43      61      89     49
# 27   18      13      65     66
# 28   91       4      55     92
# 29   89      99      98     68
# 30   66      96      92     13
# 31   69      24      88     77
# 33   91      94      62     49
# 34   71      81      98     87
# 35   34      36      70     91
# 36   30      93      97     93
# 39  100      90      54     69
# 41   97      31      70     14
# 42   87      45      85     89
# 44   41      18      72     46
# 46   99       1      91     54
# 48    0      42      71     38
# 50   76       9      84     33
# 52   73      36      79     90
# 55    9      84      71     81
# 56   57      45      89     23
# 57   60      69      58      0
# 60   19      14      97      7
# 61    9       7      99      2
# 64   79      25      64     55
# 65   97      30      56     86
# 66    9      31      98     15
# 68    8       4      53     57
# 70   86      35      91      6
# 72    4      80      61      2
# 74   44      59      70     47
# 75   96      85      79     47
# 76   62      90      92     24
# 77    3       2      77     71
# 79   70      41      68     93
# 80   18       9      51     48
# 81   62      68      92     57
# 82   29      16      76     98
# 83   12      98      78     51
# 84   81      84      82     69
# 86   65      20      84     68
# 89   95      64      88     84
# 90   77      94      91     82
# 94   17      46      61     83
# 95    6      97      84     67
# 97   28       1      66     59
# 98   66      83      70     34

# %%
df1.loc[filter1]
# Out:
#     age  height  weight  speed
# 0    57      33      97      5
# 5    79       6      73     67
# 9    30      87      74     17
# 16   65      55      80     21
# 18   10      24      82     56
# 20    5      24      96     48
# 21    9      40      56     41
# 22   43      61      89     49
# 27   18      13      65     66
# 28   91       4      55     92
# 29   89      99      98     68
# 30   66      96      92     13
# 31   69      24      88     77
# 33   91      94      62     49
# 34   71      81      98     87
# 35   34      36      70     91
# 36   30      93      97     93
# 39  100      90      54     69
# 41   97      31      70     14
# 42   87      45      85     89
# 44   41      18      72     46
# 46   99       1      91     54
# 48    0      42      71     38
# 50   76       9      84     33
# 52   73      36      79     90
# 55    9      84      71     81
# 56   57      45      89     23
# 57   60      69      58      0
# 60   19      14      97      7
# 61    9       7      99      2
# 64   79      25      64     55
# 65   97      30      56     86
# 66    9      31      98     15
# 68    8       4      53     57
# 70   86      35      91      6
# 72    4      80      61      2
# 74   44      59      70     47
# 75   96      85      79     47
# 76   62      90      92     24
# 77    3       2      77     71
# 79   70      41      68     93
# 80   18       9      51     48
# 81   62      68      92     57
# 82   29      16      76     98
# 83   12      98      78     51
# 84   81      84      82     69
# 86   65      20      84     68
# 89   95      64      88     84
# 90   77      94      91     82
# 94   17      46      61     83
# 95    6      97      84     67
# 97   28       1      66     59
# 98   66      83      70     34

# %%
filter2=df1['age']>50

# %%
df1[filter1&filter2]
# Out:
#     age  height  weight  speed
# 0    57      33      97      5
# 5    79       6      73     67
# 16   65      55      80     21
# 28   91       4      55     92
# 29   89      99      98     68
# 30   66      96      92     13
# 31   69      24      88     77
# 33   91      94      62     49
# 34   71      81      98     87
# 39  100      90      54     69
# 41   97      31      70     14
# 42   87      45      85     89
# 46   99       1      91     54
# 50   76       9      84     33
# 52   73      36      79     90
# 56   57      45      89     23
# 57   60      69      58      0
# 64   79      25      64     55
# 65   97      30      56     86
# 70   86      35      91      6
# 75   96      85      79     47
# 76   62      90      92     24
# 79   70      41      68     93
# 81   62      68      92     57
# 84   81      84      82     69
# 86   65      20      84     68
# 89   95      64      88     84
# 90   77      94      91     82
# 98   66      83      70     34

# %%
df1.loc[filter1&filter2]
# Out:
#     age  height  weight  speed
# 0    57      33      97      5
# 5    79       6      73     67
# 16   65      55      80     21
# 28   91       4      55     92
# 29   89      99      98     68
# 30   66      96      92     13
# 31   69      24      88     77
# 33   91      94      62     49
# 34   71      81      98     87
# 39  100      90      54     69
# 41   97      31      70     14
# 42   87      45      85     89
# 46   99       1      91     54
# 50   76       9      84     33
# 52   73      36      79     90
# 56   57      45      89     23
# 57   60      69      58      0
# 64   79      25      64     55
# 65   97      30      56     86
# 70   86      35      91      6
# 75   96      85      79     47
# 76   62      90      92     24
# 79   70      41      68     93
# 81   62      68      92     57
# 84   81      84      82     69
# 86   65      20      84     68
# 89   95      64      88     84
# 90   77      94      91     82
# 98   66      83      70     34

# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmila-Nri/Python-mini-project-/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install Matplotlib

# %%
from matplotlib import pyplot as plt

# %%
import random
x=[]
y=[]
#loop comprehension
[x. append(random.randint(0,25))for _ in range(10,20)]
[y.append(random.randint(0,25))for _ in range (10,20)]
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
print(x)
# Out:
# [8, 12, 24, 1, 12, 4, 3, 17, 10, 8]

# %%
print(y)
# Out:
# [14, 1, 1, 0, 20, 1, 14, 8, 20, 4]

# %%
plt.plot(x,y)
